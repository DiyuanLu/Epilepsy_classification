# %%
import numpy as np
import mne
import csv
import matplotlib.pyplot as plt
import codecs
from mne.time_frequency import tfr_morlet, psd_multitaper
import tensorflow as tf
import os
import fnmatch
import random
from sklearn.decomposition import PCA

# %%
# %matplotlib notebook

# %%
# def tensor_summary_value_to_variable():
#     fb = np.frombuffer(v.tensor.tensor_content, dtype = numpy.float32)
#     shape = []
#     for d in v.tensor.tensor_shape.dim:
#         shape.append(d.size)
#     fb = fb.reshape(shape)
#     var = tf.Variable(fb)
#     return var

sess=tf.Session()    
#First let's load meta graph and restore weights
saver = tf.train.import_meta_graph('/home/elu/LU/2_Neural_Network/2_NN_projects_codes/Epilepsy/Epilepsy_classification/results/whole_batch100_ds8_cnn/2018-04-08T12-23-36/model/batch2000.meta')
saver.restore(sess,tf.train.latest_checkpoint('/home/elu/LU/2_Neural_Network/2_NN_projects_codes/Epilepsy/Epilepsy_classification/results/whole_batch100_ds8_cnn/2018-04-08T12-23-36/model/'))
graph = tf.get_default_graph()
w2 = graph.get_tensor_by_name("loss/:0")
# Out:
# INFO:tensorflow:Restoring parameters from /home/elu/LU/2_Neural_Network/2_NN_projects_codes/Epilepsy/Epilepsy_classification/results/whole_batch100_ds8_cnn/2018-04-08T12-23-36/model/batch2000
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-99f02a8fec7c> in <module>()
#      13 saver.restore(sess,tf.train.latest_checkpoint('/home/elu/LU/2_Neural_Network/2_NN_projects_codes/Epilepsy/Epilepsy_classification/results/whole_batch100_ds8_cnn/2018-04-08T12-23-36/model/'))
#      14 graph = tf.get_default_graph()
# ---> 15 tensor_summary_value_to_variable()
#
# <ipython-input-8-99f02a8fec7c> in tensor_summary_value_to_variable()
#       1 def tensor_summary_value_to_variable():
# ----> 2     fb = np.frombuffer(v.tensor.tensor_content, dtype = numpy.float32)
#       3     shape = []
#       4     for d in v.tensor.tensor_shape.dim:
# ...

# %%
### create dataset from files in the folder
batch_size = 1

def find_files(directory, pattern='*.csv'):
    '''fine all the files in one directory'''
    files = []
    for root, dirnames, filenames in os.walk(directory):
        for filename in fnmatch.filter(filenames, pattern):
#             print filenames
            if 'Data_F' in filename:
                label = '1'
            else:
                label = '0'
            files.append((os.path.join(root, filename), label))
                    
    return files


def read_data(filename ):
    reader = csv.reader(codecs.open(filename, 'rb', 'utf-8'))
    x_data, y_data = np.array([]), np.array([])
    for ind, row in enumerate(reader):
        x, y = row
        x_data = np.append(x_data, x)
        y_data = np.append(y_data, y)
    x_data = x_data.astype(np.float32)
    y_data = y_data.astype(np.float32)
    return x_data, y_data

filedir = "data/test_files/test_folder/ori_F"

files = find_files(filedir) 
print files

file_train = tf.convert_to_tensor(files, dtype = tf.string)
dataset = tf.data.Dataset.from_tensor_slices(file_train).repeat().batch(batch_size).shuffle(buffer_size=10000)

iter = dataset.make_initializable_iterator() # create the iterator
ele = iter.get_next()

with tf.Session() as sess:
    sess.run(iter.initializer)
    for ii in range(3):
        filename =  sess.run(ele)   # name, '1'/'0'
        batch_data = np.empty([0, 10240])
        batch_labels = np.empty([0])
        for ind in range(len(filename)):
            data = np.average(read_data(filename[ind][0]), axis=0)
            batch_data = np.vstack((batch_data, data))
            batch_labels = np.append(batch_labels, filename[ind][1])
    print("batch_data", batch_data.shape, "batch_labels", batch_labels.astype(int))
# Out:
# [('data/test_files/test_folder/ori_F/Data_F_Ind0006.csv', '1'), ('data/test_files/test_folder/ori_F/Data_F_Ind0005.csv', '1')]
# ('batch_data', (1, 10240), 'batch_labels', array([1]))

# %%
from scipy.signal import spectrogram


f, t, Sxx = spectrogram(batch_data, fs=512, nperseg=512)
plt.pcolormesh(t, f, np.log10(Sxx[0, :, :]))
plt.ylabel('Frequency [Hz]')
plt.xlabel('Time [sec]')
plt.show()
f.shape, t.shape, Sxx.shape
# Out:
# <img src="data:image/png;base64,...">
# ((257,), (22,), (1, 257, 22))

# %%
dt = 0.01
t = np.arange(0, 10, dt)
data = np.random.randn(1000) + np.sin(2 * np.pi * t)
plt.plot(data)
plt.show()
# Out:
# <img src="data:image/png;base64,...">

# %%
# nse = np.random.randn(len(t))
# r = np.exp(-t / 0.05)

# cnse = np.convolve(nse, r) * dt
# cnse = cnse[:len(t)]
# s = 0.1 * np.sin(2 * np.pi * t) + cnse

plt.subplot(211)
plt.plot(data)
plt.subplot(212)
plt.psd(data, 228, 1 / dt)

plt.show()
# Out:
# <img src="data:image/png;base64,...">

# %%
from PyEMD import EMD

s = batch_data[0, 0:]
emd = EMD()
IMFs = emd(s)

# %%
plt.plot(batch_data.T)
# plt.psd(batch_data, 256, 1 / 0.01)
# Out:
# <img src="data:image/png;base64,...">

# %%
# Out:
# <img src="data:image/png;base64,...">

# %%
plt.subplot(411)
plt.plot(IMFs[0, :])
plt.subplot(412)
plt.plot(IMFs[1, :])
plt.subplot(413)
plt.plot(IMFs[2, :])
plt.subplot(414)
plt.plot(IMFs[3, :])
plt.show()
# Out:
# <div id='aa8427e4-102e-4feb-bc90-6f42acea70a5'></div>

# %%
plt.subplot(411)
plt.plot(IMFs[4, :])
plt.subplot(412)
plt.plot(IMFs[5, :])
plt.subplot(413)
plt.plot(IMFs[6, :])
plt.subplot(414)
plt.plot(IMFs[7, :])
plt.show()

# %%
plt.subplot(411)
plt.plot(IMFs[8, :])
plt.subplot(412)
plt.plot(IMFs[9, :])
plt.subplot(413)
plt.plot(IMFs[10, :])
plt.subplot(414)
plt.plot(IMFs[11, :])
plt.show()

# %%
IMFs.shape
# Out:
# (12, 1280)

# %%
# Out:
# <img src="data:image/png;base64,...">

# %%
from PyEMD import EMD2D

image = batch_data
emd2d = EMD2D()
IMF2D = emd2d(image)

# %%
plt.plot(batch_data.T)
plt.show()##it can take a while
# Out:
# <img src="data:image/png;base64,...">

# %%
plt.imshow(IMF2D[0, :, :], aspect="auto")
plt.colorbar()
plt.show()

# %%
plt.imshow(IMF2D[1, :, :], aspect="auto")
plt.colorbar()
plt.show()

# %%
custom_raw.plot_psd(fmin=1.5, fmax=40)
# events = mne.find_events(custom_raw, stim_channel='Ch1')

# picks MEG gradiometers
# picks = mne.pick_types(raw.info, meg='grad', eeg=True, eog=False, stim=False)

# # Construct Epochs
# event_id, tmin, tmax = 1, -1., 3.
# baseline = (None, 0)
# epochs = mne.Epochs(custom_raw, events, event_id, tmin, tmax, picks=picks,
#                     baseline=baseline, reject=dict(grad=4000e-13, eog=350e-6),
#                     preload=True)

# epochs.resample(150., npad='auto')  # resample to reduce computation time
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-a41342833fc9> in <module>()
# ----> 1 custom_raw.plot_psd(fmin=1.5, fmax=40)
#       2 # events = mne.find_events(custom_raw, stim_channel='Ch1')
#       3
#       4 # picks MEG gradiometers
#       5 # picks = mne.pick_types(raw.info, meg='grad', eeg=True, eog=False, stim=False)
#
# NameError: name 'custom_raw' is not defined

# %%
# creat epochs
events = np.array([[0, 0, 1]])
event_id = dict(focal=1)
tmin = -0.1

custom_epochs = mne.EpochsArray(np.expand_dims(data, axis=0), info, events, tmin, event_id)
print custom_epochs
# Out:
# <EpochsArray  |  n_events : 1 (all good), tmin : -0.099609375 (s), tmax : 19.8984375 (s), baseline : None, ~171 kB, data loaded>

# %%
freqs = np.logspace(*np.log10([2,  40]), num=16)
n_cycles = freqs / 2.
power, itc = tfr_morlet(custom_epochs, freqs=freqs, n_cycles=n_cycles, use_fft=True, return_itc=True, decim=3, n_jobs=1)

# %%
power.plot([1], baseline=(-0.9, 0), mode='logratio', title=power.ch_names[1])

# %%
raw = mne.io.read_raw_edf("data/test_CHB_MIT/chb01_08.edf", preload=True)
print raw.info
print(raw.ch_names)
# Out:
# Channel names are not unique, found duplicates for: set([u'T8-P8']). Applying running numbers for duplicates.
# <ipython-input-164-9b36a271a01c>:1: RuntimeWarning: Channel names are not unique, found duplicates for: set([u'T8-P8']). Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf("data/test_CHB_MIT/chb01_08.edf", preload=True)
# <Info | 17 non-empty fields
#     bads : list | 0 items
#     buffer_size_sec : float | 1.0
#     ch_names : list | FP1-F7, F7-T7, T7-P7, P7-O1, FP1-F3, F3-C3, C3-P3, ...
#     chs : list | 23 items (EEG: 23)
#     comps : list | 0 items
#     custom_ref_applied : bool | False
#     dev_head_t : Transform | 3 items
#     events : list | 0 items
#     highpass : float | 0.0 Hz
#     hpi_meas : list | 0 items
#     hpi_results : list | 0 items
#     lowpass : float | 128.0 Hz
#     meas_date : int | 216153820
#     nchan : int | 23
#     proc_history : list | 0 items
#     projs : list | 0 items
#     sfreq : float | 256.0 Hz
# ...

# %%
start, stop = raw.time_as_index([100, 115])  # 100 s to 115 s data segment
# data, times = raw[:, start:stop]

data, times = raw[0:10, 0:10]  # access underlying data
raw.plot()

# %%
from mne.decoding import CSP
from mne.time_frequency import AverageTFR

from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.model_selection import StratifiedKFold, cross_val_score
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import LabelEncoder

# Examples from https://martinos.org/mne/dev/auto_examples/decoding/plot_decoding_csp_timefreq.html#sphx-glr-auto-examples-decoding-plot-decoding-csp-timefreq-py

# Extract information from the raw file
event_id = dict(ictal=1, nonictal=2) 
sfreq = raw.info['sfreq']
events = mne.find_events(raw, stim_channel='auto')
raw.pick_types(meg=False, eeg=True, stim=False, eog=False, exclude='bads')
events
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-177-b3124f06f7df> in <module>()
#      12 event_id = dict(ictal=1, nonictal=2)
#      13 sfreq = raw.info['sfreq']
# ---> 14 events = mne.find_events(raw, stim_channel='auto')
#      15 raw.pick_types(meg=False, eeg=True, stim=False, eog=False, exclude='bads')
#      16 events
#
# /home/elu/.local/lib/python2.7/site-packages/mne/event.pyc in find_events(raw, stim_channel, output, consecutive, min_duration, shortest_event, mask, uint_cast, mask_type, verbose)
#
# /home/elu/.local/lib/python2.7/site-packages/mne/utils.pyc in verbose(function, *args, **kwargs)
#     726         with use_log_level(verbose_level):
#     727             return function(*args, **kwargs)
# --> 728     return function(*args, **kwargs)
#     729
#     730
#
# ...

# %%
# Assemble the classifier using scikit-learn pipeline
clf = make_pipeline(CSP(n_components=4, reg=None, log=True, norm_trace=False),
                    LinearDiscriminantAnalysis())
n_splits = 5  # how many folds to use for cross-validation
cv = StratifiedKFold(n_splits=n_splits, shuffle=True)

# Classification & Time-frequency parameters
tmin, tmax = -.200, 2.000
n_cycles = 10.  # how many complete cycles: used to define window size
min_freq = 5.
max_freq = 25.
n_freqs = 8  # how many frequency bins to use

# Assemble list of frequency range tuples
freqs = np.linspace(min_freq, max_freq, n_freqs)  # assemble frequencies
freq_ranges = list(zip(freqs[:-1], freqs[1:]))  # make freqs list of tuples

# Infer window spacing from the max freq and number of cycles to avoid gaps
window_spacing = (n_cycles / np.max(freqs) / 2.)
centered_w_times = np.arange(tmin, tmax, window_spacing)[1:]
n_windows = len(centered_w_times)

# Instantiate label encoder
le = LabelEncoder()

# init scores
freq_scores = np.zeros((n_freqs - 1,))

# Loop through each frequency range of interest
for freq, (fmin, fmax) in enumerate(freq_ranges):

    # Infer window size based on the frequency being used
    w_size = n_cycles / ((fmax + fmin) / 2.)  # in seconds

    # Apply band-pass filter to isolate the specified frequencies
    raw_filter = raw.copy().filter(fmin, fmax, n_jobs=1, fir_design='firwin',
                                   skip_by_annotation='edge')

    # Extract epochs from filtered data, padded by window size
    epochs = mne.Epochs(raw_filter, events, event_id, tmin - w_size, tmax + w_size,
                    proj=False, baseline=None, preload=True)
    epochs.drop_bad()
    y = le.fit_transform(epochs.events[:, 2])

    X = epochs.get_data()

    # Save mean scores over folds for each frequency and time window
    freq_scores[freq] = np.mean(cross_val_score(estimator=clf, X=X, y=y,
                                                scoring='roc_auc', cv=cv,
                                                n_jobs=1), axis=0)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-173-107118979d8a> in <module>()
#      39     # Extract epochs from filtered data, padded by window size
#      40     epochs = mne.Epochs(raw_filter, events, event_id, tmin - w_size, tmax + w_size,
# ---> 41                     proj=False, baseline=None, preload=True)
#      42     epochs.drop_bad()
#      43     y = le.fit_transform(epochs.events[:, 2])
#
# /home/elu/.local/lib/python2.7/site-packages/mne/epochs.pyc in __init__(self, raw, events, event_id, tmin, tmax, baseline, picks, preload, reject, flat, proj, decim, reject_tmin, reject_tmax, detrend, on_missing, reject_by_annotation, verbose)
#
# /home/elu/.local/lib/python2.7/site-packages/mne/utils.pyc in verbose(function, *args, **kwargs)
#     726         with use_log_level(verbose_level):
#     727             return function(*args, **kwargs)
# ...
